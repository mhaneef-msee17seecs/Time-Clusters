# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
traindata = pd.read_csv('smalldata.txt', sep = ',')

# %%
import numpy as np
t = np.zeros(6000) #time
w = np.zeros(6000) #address
x = np.zeros(6000) #row
y = np.zeros(6000) #column
z = np.zeros(6000) #delay
a = np.zeros(6000) #addressgrowth
b = np.zeros(6000) #columngrowth
c = np.zeros(6000) #rowgrowth

# %%
for i in range (0, 5136):
    w[i] = traindata.address[i+1] - traindata.address[i]

# %%
for i in range (0, 5136):
    x[i] = traindata.column[i+1] - traindata.column[i]

# %%
for i in range (0, 5136):
    y[i] = traindata.row[i+1] - traindata.row[i]

# %%
for i in range (0, 5136):
    t[i] = traindata.time[i+1] - traindata.time[i]

# %%
for i in range (0, 5136):
    z[i] = traindata.delay[i]

# %%
for i in range (0, 5136):
    if (traindata.address[i+1] != traindata.address[i]):
        a[i] = (traindata.address[i+1] - traindata.address[i])/(traindata.address[i+1])
    else:
        a[i] = 0

# %%
for i in range (0, 5136):
    if (traindata.column[i+1] != traindata.column[i]):
        b[i] = (traindata.column[i+1] - traindata.column[i])/(traindata.column[i+1])
    else:
        b[i] = 0
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in longlong_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.09090909090909091

# %%
print(traindata.column[11] - traindata.column[10])/(traindata.column[11]))
# Out:
#   File "<ipython-input-269-92d07b95a90a>", line 1
#     print(traindata.column[11] - traindata.column[10])/(traindata.column[11]))
#                                                                              ^
# SyntaxError: invalid syntax

# %%
for i in range (0, 5136):
    if (traindata.row[i+1] != traindata.row[i]):
        c[i] = (traindata.row[i+1] - traindata.row[i])/(traindata.row[i+1])
    else:
        c[i] = 0

# %%
print(traindata.columns)
# Out:
# Index(['time', 'address', 'binaryaddress', 'bank', 'row', 'column', 'delay',
#        'command'],
#       dtype='object')

# %%
import csv
#Working Code
with open('differencedata.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Addressdiff', 'addressgrowth','Columndiff', 'columngrowth', 'Rowdiff', 'rowgrowth', 'timediff', 'delay'])
    for i in range (0, 5137):
        writer.writerow([w[i], a[i], x[i], b[i], y[i], c[i], t[i], z[i]])

# %%
import seaborn as sns
newdata = pd.read_csv('differencedata.csv')
# Create the default pairplot
newdata = newdata.abs()

# %%
sns.pairplot(newdata, hue="delay")

# %%
from sklearn import preprocessing
import numpy as np
X = np.array(newdata.values)
plt.scatter(X[:,2], X[:,7], cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.title('Delay vs Time')
plt.xlabel('Time Diff in ps')
plt.ylabel('Latency')
plt.figure(figsize=(50,50))

# %%
with open('changes.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['address', 'addressgrowth', 'column', 'columngrowth', 'row', 'rowgrowth', 'time', 'delay'])
    
    for i in range (0, 5136):
        if (newdata.delay[i] != newdata.delay[i+1]):
            writer.writerow([newdata.Addressdiff[i], newdata.addressgrowth[i], newdata.Columndiff[i], newdata.columngrowth[i], newdata.Rowdiff[i], 
                             newdata.rowgrowth[i], newdata.timediff[i], newdata.delay[i]])
            writer.writerow([newdata.Addressdiff[i+1], newdata.addressgrowth[i+1], newdata.Columndiff[i+1], newdata.columngrowth[i+1], newdata.Rowdiff[i+1], 
# 2105   16655040.0   2.522552e-01    88.0      0.134146   2033.0   0.252265
# 2107   66214720.0   5.007189e-01   152.0      0.301587   8083.0   0.500743
# 2109   20009920.0   1.782949e-01   392.0      0.437500   2443.0   0.178334
# 2111   68584512.0   1.571422e+00   136.0      0.178947   8372.0   1.571616
# 2113   27435072.0   3.859749e-01     8.0      0.010417   3349.0   0.386007
# 2115   66881984.0   1.593205e+01   312.0      0.684211   8164.0  15.945312
# 2117  114831488.0   9.647318e-01   528.0      0.536585  14017.0   0.964760
# 2119   39120256.0   4.895589e-01   432.0      0.782609   4775.0   0.489543
# 2499         64.0   7.807584e-07     8.0      0.026316      0.0   0.000000
# 2997          0.0   0.000000e+00     0.0      0.000000      0.0   0.000000
#
#          time     delay
# 0      1250.0   31250.0
# 1      1250.0   35000.0
# 3      1250.0   38750.0
# 5      1250.0   42500.0
# 7      1250.0   46250.0
# 9      1250.0   50000.0
# 11     1250.0   53750.0
# 13     1250.0   57500.0
# 15    22500.0   61250.0
# 17     5000.0   43750.0
# 19     5000.0   71250.0
# 21     5000.0  113750.0
# 23     5000.0  156250.0
# 25     5000.0  198750.0
# 27     5000.0  241250.0
# 29     5000.0  283750.0
# 31     5000.0  326250.0
# 33     5000.0  368750.0
# 35    32500.0  411250.0
# 37    47500.0  383750.0
# 39    47500.0  341250.0
# 41    47500.0  298750.0
# 43    47500.0  256250.0
# 45    47500.0  213750.0
# 47    47500.0  171250.0
# 49    47500.0  128750.0
# 51    47500.0   86250.0
# 73    47500.0  426250.0
# 237   47500.0  331250.0
# 239    5000.0  288750.0
# 759   47500.0  246250.0
# 761   47500.0  203750.0
# 763    5000.0  161250.0
# 971   32500.0   98750.0
# 1629   5000.0  373750.0
# 1631  37500.0  416250.0
# 1733   5000.0  141250.0
# 1735  32500.0  183750.0
# 2103   5000.0  108750.0
# 2105   5000.0  151250.0
# 2107   5000.0  193750.0
# 2109   5000.0  236250.0
# 2111   5000.0  278750.0
# 2113   5000.0  321250.0
# 2115  32500.0  363750.0
# 2117   5000.0  378750.0
# 2119  42500.0  421250.0
# 2499   5000.0  336250.0
# 2997      0.0       0.0

# %%
sns.pairplot(changedata, hue="delay")

# %%
import numpy as np
X = np.array(changedata.values)
plt.scatter(X[:,1], X[:,7], cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.title('Delay vs Address Rate of Change')
plt.xlim(-1,2.5)
plt.ylim (0, 100000) #0,1000
plt.xlabel('Address growth')
plt.ylabel('Latency')
plt.figure(figsize=(50,50))

# %%
X = np.array(changedata.values)
plt.scatter(X[:,3], X[:,7], cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.title('Delay vs Column Rate of Change')
plt.xlim(-1,2.5)
plt.ylim (0, 100000) #0,1000
plt.xlabel('Column growth')
plt.ylabel('Latency')
plt.figure(figsize=(50,50))

# %%
plt.scatter(X[:,5], X[:,7], cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.title('Delay vs Row Rate of Change')
plt.xlim(0.25,2.5)
#plt.ylim (0, 100000) #0,1000
plt.xlabel('Row growth')
plt.ylabel('Latency')
plt.figure(figsize=(50,50))

# %%
import numpy as np
X = np.array(newdata.values)
plt.scatter(X[:,1], X[:,7], cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.title('Delay vs Address Rate of Change')
plt.xlim(0,1)
plt.ylim (19000, 80000) #0,1000
plt.xlabel('Address growth')
plt.ylabel('Latency')
plt.figure(figsize=(50,50))

# %%
#Testing on the standardizing/normalizing the features data and not the target variable (delay)

from sklearn import preprocessing
import numpy as np

features= ['address','column','row','time']
X = changedata[features]
Y = changedata['delay']

# %%
x = np.array(X)
y = preprocessing.scale(X)

# %%
plt.scatter(y[:,0], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
#plt.xlim(-2, 4)
#plt.ylim(-2, 4)
plt.title('Address Difference vs. Delay')
plt.xlabel('Address Difference')
plt.ylabel('Delay')
plt.figure(figsize=(50,50))

# %%
plt.scatter(y[:,1], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
#plt.xlim(-2, 4)
#plt.ylim(-2, 4)
plt.title('Column Difference vs. Delay')
plt.xlabel('Column Difference')
plt.ylabel('Delay')
plt.figure(figsize=(50,50))

# %%
plt.scatter(y[:,2], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
#plt.xlim(-2, 4)
#plt.ylim(-2, 4)
plt.title('Row Difference vs. Delay')
plt.xlabel('Row Difference')
plt.ylabel('Delay')
plt.figure(figsize=(50,50))

# %%
plt.scatter(y[:,3], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
#plt.xlim(-2, 4)
#plt.ylim(-2, 4)
plt.title('Time Difference vs. Delay')
plt.xlabel('Time Difference')
plt.ylabel('Delay')
plt.figure(figsize=(50,50))

# %%
changedata.skew()
# Out:
# address    1.385132
# column     1.042466
# row        1.385142
# time       0.617453
# delay      0.122178
# dtype: float64

# %%
changedata.kurtosis()
# Out:
# address    1.026313
# column    -0.320049
# row        1.026290
# time      -1.517104
# delay     -1.313743
# dtype: float64

# %%
x = np.array(X) #X only contains the features so normalizing the features
y = preprocessing.scale(X) #y contains normalized featrues but not the delay

changedata['address'] = np.log(changedata['address'])
print (changedata['address'])
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0        4.158883
# 1        4.158883
# 3        4.158883
# 5        4.158883
# 7        4.158883
# 9        4.158883
# 11       4.158883
# 13       4.158883
# 15       4.158883
# 17       4.158883
# 19      15.484080
# 21      17.148417
# 23      17.459680
# 25      15.256323
# 27      18.483114
# 29      17.757250
# 31      17.184381
# 33      16.785891
# 35       4.158883
# 37       4.158883
# 39       4.158883
# 41       4.158883
# 43       4.158883
# 45       4.158883
# 47       4.158883
# 49       4.158883
# 51       4.158883
# 73      17.923492
# 237     17.234425
# 239      4.158883
# 759      4.158883
# 761      4.158883
# 763      4.158883
# 971     16.362483
# 1629    18.412874
# 1631    18.310852
# 1733    17.824649
# 1735    17.560758
# 2103    17.490885
# 2105    16.628223
# 2107    18.008413
# 2109    16.811739
# 2111    18.043577
# 2113    17.127333
# 2115    18.018440
# 2117    18.558976
# 2119    17.482151
# 2499     4.158883
# 2997         -inf
# Name: address, dtype: float64

# %%
plt.scatter(changedata['address'], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')

# %%
changedata['column'] = np.log(changedata['column'])
print (changedata['column'])
# Out:
# 0       2.079442
# 1       2.079442
# 3       2.079442
# 5       2.079442
# 7       2.079442
# 9       2.079442
# 11      2.079442
# 13      2.079442
# 15      2.079442
# 17      2.079442
# 19      6.298949
# 21      5.929589
# 23      5.768321
# 25      5.908083
# 27      6.342121
# 29      5.991465
# 31      5.971262
# 33      6.590301
# 35      2.079442
# 37      2.079442
# 39      2.079442
# 41      2.079442
# 43      2.079442
# 45      2.079442
# 47      2.079442
# 49      2.079442
# 51      2.079442
# 73      5.411646
# 237     6.369901
# 239     2.079442
# 759     2.079442
# 761     2.079442
# 763     2.079442
# 971     6.486161
# 1629    4.718499
# 1631    6.510258
# 1733        -inf
# 1735    3.871201
# 2103    5.768321
# 2105    4.477337
# 2107    5.023881
# 2109    5.971262
# 2111    4.912655
# 2113    2.079442
# 2115    5.743003
# 2117    6.269096
# 2119    6.068426
# 2499    2.079442
# 2997        -inf
# Name: column, dtype: float64
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(changedata['column'], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')

# %%
changedata['row'] = np.log(changedata['row'])
print (changedata['row'])
# Out:
# 0           -inf
# 1           -inf
# 3           -inf
# 5           -inf
# 7           -inf
# 9           -inf
# 11          -inf
# 13          -inf
# 15          -inf
# 17          -inf
# 19      6.472346
# 21      8.137396
# 23      8.448700
# 25      6.246107
# 27      9.472243
# 29      8.746398
# 31      8.173575
# 33      7.775276
# 35          -inf
# 37          -inf
# 39          -inf
# 41          -inf
# 43          -inf
# 45          -inf
# 47          -inf
# 49          -inf
# 51          -inf
# 73      8.912608
# 237     8.223359
# 239         -inf
# 759         -inf
# 761         -inf
# 763         -inf
# 971     7.351158
# 1629    9.401952
# 1631    9.299998
# 1733    8.813736
# 1735    8.549854
# 2103    8.479907
# 2105    7.617268
# 2107    8.997518
# 2109    7.800982
# 2111    9.032648
# 2113    8.116417
# 2115    9.007490
# 2117    9.548026
# 2119    8.471149
# 2499        -inf
# 2997        -inf
# Name: row, dtype: float64
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(changedata['row'], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')

# %%
changedata['time'] = np.log(changedata['time'])
print (changedata['time'])
# Out:
# 0        7.130899
# 1        7.130899
# 3        7.130899
# 5        7.130899
# 7        7.130899
# 9        7.130899
# 11       7.130899
# 13       7.130899
# 15      10.021271
# 17       8.517193
# 19       8.517193
# 21       8.517193
# 23       8.517193
# 25       8.517193
# 27       8.517193
# 29       8.517193
# 31       8.517193
# 33       8.517193
# 35      10.388995
# 37      10.768485
# 39      10.768485
# 41      10.768485
# 43      10.768485
# 45      10.768485
# 47      10.768485
# 49      10.768485
# 51      10.768485
# 73      10.768485
# 237     10.768485
# 239      8.517193
# 759     10.768485
# 761     10.768485
# 763      8.517193
# 971     10.388995
# 1629     8.517193
# 1631    10.532096
# 1733     8.517193
# 1735    10.388995
# 2103     8.517193
# 2105     8.517193
# 2107     8.517193
# 2109     8.517193
# 2111     8.517193
# 2113     8.517193
# 2115    10.388995
# 2117     8.517193
# 2119    10.657259
# 2499     8.517193
# 2997         -inf
# Name: time, dtype: float64
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(changedata['time'], Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k